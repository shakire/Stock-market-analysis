# %%
pip install pyyaml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yaml

# %%
with open("C:\\Data science\\Project 2 - data driven stock analysis\\data\\2023-10\\2023-10-03_05-30-00.yaml","r") as file:
    data = yaml.safe_load(file)

# %%
import pandas as pd

df = pd.DataFrame(data)
df
# Out:
#         Ticker     close                 date      high       low    month  \
# 0         SBIN    602.95  2023-10-03 05:30:00    604.90    589.60  2023-10
# 1   BAJFINANCE   7967.60  2023-10-03 05:30:00   7975.50   7755.00  2023-10
# 2        TITAN   3196.25  2023-10-03 05:30:00   3212.50   3114.40  2023-10
# 3          ITC    439.75  2023-10-03 05:30:00    442.90    439.25  2023-10
# 4          TCS   3513.85  2023-10-03 05:30:00   3534.20   3480.10  2023-10
# 5           LT   3073.25  2023-10-03 05:30:00   3077.45   2995.10  2023-10
# 6   TATACONSUM    861.20  2023-10-03 05:30:00    868.75    853.49  2023-10
# 7     RELIANCE   1159.08  2023-10-03 05:30:00   1167.80   1158.00  2023-10
# 8      HCLTECH   1238.70  2023-10-03 05:30:00   1256.70   1222.70  2023-10
# 9     JSWSTEEL    770.25  2023-10-03 05:30:00    776.55    768.00  2023-10
# 10  ULTRACEMCO   8304.90  2023-10-03 05:30:00   8377.00   8221.20  2023-10
# ...

# %%
import os

# %%
folder_path = "C:\\Data science\\Project 2 - data driven stock analysis\\data\\2023-10"
oct_data =[]
for filename in os.listdir(folder_path):
    if filename.endswith(".yaml"):
        file_path = os.path.join(folder_path, filename)
        with open(file_path, 'r') as file:
            data = yaml.safe_load(file)
            if isinstance(data, list):
                oct_data.extend(data)
            elif isinstance(data, dict):
                oct_data.append(data)

df_oct = pd.DataFrame(oct_data)

# %%
df_oct
# Out:
#          Ticker    close                 date     high      low    month  \
# 0          SBIN   602.95  2023-10-03 05:30:00   604.90   589.60  2023-10
# 1    BAJFINANCE  7967.60  2023-10-03 05:30:00  7975.50  7755.00  2023-10
# 2         TITAN  3196.25  2023-10-03 05:30:00  3212.50  3114.40  2023-10
# 3           ITC   439.75  2023-10-03 05:30:00   442.90   439.25  2023-10
# 4           TCS  3513.85  2023-10-03 05:30:00  3534.20  3480.10  2023-10
# ..          ...      ...                  ...      ...      ...      ...
# 995    HINDALCO   459.50  2023-10-31 05:30:00   465.00   453.25  2023-10
# 996  HEROMOTOCO  3088.35  2023-10-31 05:30:00  3139.60  3080.15  2023-10
# 997    AXISBANK   981.85  2023-10-31 05:30:00   998.00   978.00  2023-10
# 998    HDFCBANK  1476.50  2023-10-31 05:30:00  1504.00  1474.00  2023-10
# 999  BAJAJ-AUTO  5314.05  2023-10-31 05:30:00  5366.15  5292.60  2023-10
#
#         open    volume
# 0     596.60  15322196
# 1    7780.80    944555
# ...

# %%
folder_path = "C:\\Data science\\Project 2 - data driven stock analysis\\data"
all_data = []
for root, dirs, files in os.walk(folder_path):
    for filename in files:
        if filename.endswith('.yaml') or filename.endswith('.yml'):
            file_path = os.path.join(root, filename)
            with open(file_path, 'r') as file:
                data = yaml.safe_load(file)
                if isinstance(data, list):
                    all_data.extend(data)
                elif isinstance(data, dict):
                    all_data.append(data)

df_all = pd.DataFrame(all_data)

# %%
df_all
# Out:
#            Ticker    close                 date    high      low    month  \
# 0            SBIN   602.95  2023-10-03 05:30:00   604.9   589.60  2023-10
# 1      BAJFINANCE  7967.60  2023-10-03 05:30:00  7975.5  7755.00  2023-10
# 2           TITAN  3196.25  2023-10-03 05:30:00  3212.5  3114.40  2023-10
# 3             ITC   439.75  2023-10-03 05:30:00   442.9   439.25  2023-10
# 4             TCS  3513.85  2023-10-03 05:30:00  3534.2  3480.10  2023-10
# ...           ...      ...                  ...     ...      ...      ...
# 14195    HINDALCO   652.10  2024-11-22 05:30:00   657.3   647.40  2024-11
# 14196  HEROMOTOCO  4794.10  2024-11-22 05:30:00  4808.4  4742.00  2024-11
# 14197    AXISBANK  1142.40  2024-11-22 05:30:00  1147.9  1127.55  2024-11
# 14198    HDFCBANK  1745.60  2024-11-22 05:30:00  1754.3  1729.55  2024-11
# 14199  BAJAJ-AUTO  9481.65  2024-11-22 05:30:00  9602.9  9444.10  2024-11
#
#           open    volume
# 0       596.60  15322196
# 1      7780.80    944555
# ...

# %%
df_all.to_csv("combined_all.csv")
